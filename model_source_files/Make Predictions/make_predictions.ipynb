# %% [markdown]
# # Demand Predictor Model Accuracy

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
import joblib
import matplotlib.pyplot as plt

# read data from csv files
data = pd.read_csv('demand_data.csv')

#prepare x and y data
x_data = data.drop(columns=['demand'])
y_data = data['demand']

#prepare and train data test data 
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2)

# %%
plt.scatter(data['year'], data['demand'], label='year vs. demand')
plt.xlabel('year')
plt.ylabel('demand')
plt.legend()
plt.title('Scatter Plot')
plt.show()

# %%
plt.scatter(data['job_role'], data['demand'], label='job_role vs. demand')
plt.xlabel('job role')
plt.ylabel('demand')
plt.legend()
plt.title('Scatter Plot')
plt.show()

# %%
#using decision tree regressor as the model algorythmn
model = LinearRegression()
model.fit(x_train, y_train)

#calculate accuracy
predictions = model.predict(x_test)
mean_squared_error(y_test, predictions)
# Out:
# 148.8585448411974

# %%
np.sqrt(mean_squared_error(y_test, predictions))
# Out:
# 12.2007600108025

# %% [markdown]
# # Dump Model

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
import joblib

# read data from csv files
demand_data = pd.read_csv('demand_data.csv')

#prepare x and y data
x_data = demand_data.drop(columns=['demand'])
y_data = demand_data['demand']

#using decision tree regressor as the model algorythmn
model = LinearRegression()
model.fit(x_data, y_data)

joblib.dump(model, 'demand-predictor.pkl')
# Out:
# ['demand-predictor.pkl']

# %% [markdown]
# # Load Model

# %%
import joblib

model = joblib.load('demand-predictor.pkl')

predictions = model.predict([[2023, 0]])
predictions
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([46.54773891])
